# %%
# !pip install pillow
# Out:
# Requirement already satisfied: pillow in d:\software\anaconda\lib\site-packages (10.3.0)

# %%
from PIL import Image

# %%
dir = 'C:/Users/Anson/Documents/TGMT-Lop7/img'

# %%
image_path = dir + '/kazuki06.jpg'
print(image_path)
# Out:
# C:/Users/Anson/Documents/TGMT-Lop7/img/kazuki06.jpg

# %%
img01 = Image.open(image_path)

# %%
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1650>

# %%
print("Định dang ảnh: ", img01.format)
# Out:
# Định dang ảnh:  JPEG

# %%
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (1200, 1650)

# %%
new_img_01_path = dir + '/new_01.JPG'
new_img_png_01_path = dir + '/new_01.PNG'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
img01.close()
